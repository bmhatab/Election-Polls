# %%
import pandas as pd
import openpyxl

# Import data locally
df = pd.read_csv('elections_gomoa_central.csv',header=0)
df.head()
# Out:
#        Polling station name  NPP  NDC  Total valid votes  Rejected votes  \
# 0            SPECIAL VOTING  157   31                188               0
# 1    DA PRIM SCH AKWAMU (A)  197   88                292               3
# 2    DA PRIM SCH AKWAMU (B)  199  100                306               6
# 3  DA PRIM SCH KWAME ADWER    81  153                237              10
# 4     DA PRIM SCH ABAMKWAIM   69  115                220               2
#
#    Total votes cast  Reg. votes
# 0               188         208
# 1               295         444
# 2               312         442
# 3               247         295
# 4               222         273

# %%
# NPP Wins in Polls
npp_wins = df.loc[(df['NPP'] > df['NDC'])].copy()
npp_wins
# Out:
#        Polling station name  NPP  NDC  Total valid votes  Rejected votes  \
# 0            SPECIAL VOTING  157   31                188               0
# 1    DA PRIM SCH AKWAMU (A)  197   88                292               3
# 2    DA PRIM SCH AKWAMU (B)  199  100                306               6
# 8   METH CHURCH AFRANSI (A)  269  154                448               8
# 9   METH CHURCH AFRANSI (B)  236  186                438               3
# ..                      ...  ...  ...                ...             ...
# 79   COMMUNITY CENTRE JUKWA  336  143                487              12
# 80    DA PRIM SCH MANSO (A)  258   87                362               8
# 81    DA PRIM SCH MANSO (B)  253  101                366               3
# 82   COMMUNITY CENTRE MANSO   90   46                140               4
# 83      DA JHS MANGOASE (A)  196  193                395               2
#
#     Total votes cast  Reg. votes
# 0                188         208
# 1                295         444
# 2                312         442
# 8                456         618
# 9                441         616
# ..               ...         ...
# 79               499         685
# 80               370         460
# 81               369         459
# 82               144         201
# 83               397         478
#
# [65 rows x 7 columns]

# %%
# For NPP percentage wins
percent_npp_votes = (npp_wins['NPP']/npp_wins['Total valid votes'])*100
npp_wins['Percentage of votes'] = percent_npp_votes
npp_wins
# Out:
#        Polling station name  NPP  NDC  Total valid votes  Rejected votes  \
# 0            SPECIAL VOTING  157   31                188               0
# 1    DA PRIM SCH AKWAMU (A)  197   88                292               3
# 2    DA PRIM SCH AKWAMU (B)  199  100                306               6
# 8   METH CHURCH AFRANSI (A)  269  154                448               8
# 9   METH CHURCH AFRANSI (B)  236  186                438               3
# ..                      ...  ...  ...                ...             ...
# 79   COMMUNITY CENTRE JUKWA  336  143                487              12
# 80    DA PRIM SCH MANSO (A)  258   87                362               8
# 81    DA PRIM SCH MANSO (B)  253  101                366               3
# 82   COMMUNITY CENTRE MANSO   90   46                140               4
# 83      DA JHS MANGOASE (A)  196  193                395               2
#
#     Total votes cast  Reg. votes  Percentage of votes
# 0                188         208            83.510638
# 1                295         444            67.465753
# 2                312         442            65.032680
# 8                456         618            60.044643
# 9                441         616            53.881279
# ..               ...         ...                  ...
# 79               499         685            68.993840
# 80               370         460            71.270718
# 81               369         459            69.125683
# 82               144         201            64.285714
# 83               397         478            49.620253
#
# [65 rows x 8 columns]

# %%
# Percentage win among total poll 
percent_poll_wins = (npp_wins.shape[0]/df.shape[0])*100
percent_poll_wins
# Out:
# 77.38095238095238

# %%
# Percentage of Registered Voters who did not vote for winning polls
reg_vote_not = ((npp_wins['Reg. votes'] - npp_wins['Total votes cast']) / npp_wins['Reg. votes'])*100
npp_wins['Percentage of non-voters'] = reg_vote_not
npp_wins
# Out:
#        Polling station name  NPP  NDC  Total valid votes  Rejected votes  \
# 0            SPECIAL VOTING  157   31                188               0
# 1    DA PRIM SCH AKWAMU (A)  197   88                292               3
# 2    DA PRIM SCH AKWAMU (B)  199  100                306               6
# 8   METH CHURCH AFRANSI (A)  269  154                448               8
# 9   METH CHURCH AFRANSI (B)  236  186                438               3
# ..                      ...  ...  ...                ...             ...
# 79   COMMUNITY CENTRE JUKWA  336  143                487              12
# 80    DA PRIM SCH MANSO (A)  258   87                362               8
# 81    DA PRIM SCH MANSO (B)  253  101                366               3
# 82   COMMUNITY CENTRE MANSO   90   46                140               4
# 83      DA JHS MANGOASE (A)  196  193                395               2
#
#     Total votes cast  Reg. votes  Percentage of votes  \
# 0                188         208            83.510638
# 1                295         444            67.465753
# 2                312         442            65.032680
# 8                456         618            60.044643
# 9                441         616            53.881279
# ..               ...         ...                  ...
# 79               499         685            68.993840
# 80               370         460            71.270718
# 81               369         459            69.125683
# 82               144         201            64.285714
# 83               397         478            49.620253
#
#     Percentage of non-voters
# 0                   9.615385
# 1                  33.558559
# 2                  29.411765
# 8                  26.213592
# 9                  28.409091
# ..                       ...
# 79                 27.153285
# 80                 19.565217
# 81                 19.607843
# 82                 28.358209
# 83                 16.945607
#
# [65 rows x 9 columns]

# %%
# Percentage margin of winning over NDC
win_margin_percent = ((npp_wins['NPP'] - npp_wins['NDC'])/ npp_wins['Total valid votes'])*100
npp_wins['Percentage of win margin'] = win_margin_percent
npp_wins
# Out:
#        Polling station name  NPP  NDC  Total valid votes  Rejected votes  \
# 0            SPECIAL VOTING  157   31                188               0
# 1    DA PRIM SCH AKWAMU (A)  197   88                292               3
# 2    DA PRIM SCH AKWAMU (B)  199  100                306               6
# 8   METH CHURCH AFRANSI (A)  269  154                448               8
# 9   METH CHURCH AFRANSI (B)  236  186                438               3
# ..                      ...  ...  ...                ...             ...
# 79   COMMUNITY CENTRE JUKWA  336  143                487              12
# 80    DA PRIM SCH MANSO (A)  258   87                362               8
# 81    DA PRIM SCH MANSO (B)  253  101                366               3
# 82   COMMUNITY CENTRE MANSO   90   46                140               4
# 83      DA JHS MANGOASE (A)  196  193                395               2
#
#     Total votes cast  Reg. votes  Percentage of votes  \
# 0                188         208            83.510638
# 1                295         444            67.465753
# 2                312         442            65.032680
# 8                456         618            60.044643
# 9                441         616            53.881279
# ..               ...         ...                  ...
# 79               499         685            68.993840
# 80               370         460            71.270718
# 81               369         459            69.125683
# 82               144         201            64.285714
# 83               397         478            49.620253
#
#     Percentage of non-voters  Percentage of win margin
# 0                   9.615385                 67.021277
# 1                  33.558559                 37.328767
# 2                  29.411765                 32.352941
# 8                  26.213592                 25.669643
# 9                  28.409091                 11.415525
# ..                       ...                       ...
# 79                 27.153285                 39.630390
# 80                 19.565217                 47.237569
# 81                 19.607843                 41.530055
# 82                 28.358209                 31.428571
# 83                 16.945607                  0.759494
#
# [65 rows x 10 columns]

# %%
# NPP Losses in Polls
npp_losses = df.loc[(df['NPP'] < df['NDC'])].copy()
npp_losses
# Out:
#              Polling station name  NPP  NDC  Total valid votes  \
# 3        DA PRIM SCH KWAME ADWER    81  153                237
# 4           DA PRIM SCH ABAMKWAIM   69  115                220
# 5         DA PRIM SCH AFRANSI (A)  138  144                294
# 6         DA PRIM SCH AFRANSI (B)  126  179                313
# 7                  DA JHS AFRANSI   51   64                125
# 13     ANGLICAN PRIM SCHOOL OFASO  121  126                251
# 15        DA JHS UPPER OBUASI (A)  149  251                415
# 16        DA JHS UPPER OBUASI (B)  154  244                413
# 17  COMMUNITY CENTRE UPPER OBUASI  104  168                279
# 18   DA PRIM SCH LOWER OBUASI (A)  171  213                394
# 19   DA PRIM SCH LOWER OBUASI (B)  139  236                392
# 20     MARKET SQUARE LOWER OBUASI  118  177                303
# 21          METH PRIM SCH GYAAMAN  165  299                486
# 23             DA JHS GYAAMAN (A)  106  170                281
# 24             DA JHS GYAAMAN (B)  142  163                313
# 25           METH. CHURCH GYAAMAN  140  169                311
# 26         METH. PRIM SCH ESIKUMA  176  242                451
# 27           METH. CHURCH ESIKUMA  128  145                282
# 36   COMMUNITY CENTRE ACHIASE (A)  158  161                333
#
#     Rejected votes  Total votes cast  Reg. votes
# 3               10               247         295
# 4                2               222         273
# 5                2               296         409
# 6                6               319         407
# 7                0               125         179
# 13               3               254         296
# 15              10               416         506
# 16               5               418         505
# 17              10               289         379
# 18               2               396         536
# 19               8               400         535
# 20               5               308         457
# 21               5               491         636
# 23               3               284         511
# 24               7               320         509
# 25               2               313         441
# 26               8               459         594
# 27               6               288         364
# 36               7               340         421

# %%
# For NPP percentage losses
percent_npp_votes = (npp_losses['NPP']/npp_losses['Total valid votes'])*100
npp_losses['Percentage of votes'] = percent_npp_votes
npp_losses
# Out:
#              Polling station name  NPP  NDC  Total valid votes  \
# 3        DA PRIM SCH KWAME ADWER    81  153                237
# 4           DA PRIM SCH ABAMKWAIM   69  115                220
# 5         DA PRIM SCH AFRANSI (A)  138  144                294
# 6         DA PRIM SCH AFRANSI (B)  126  179                313
# 7                  DA JHS AFRANSI   51   64                125
# 13     ANGLICAN PRIM SCHOOL OFASO  121  126                251
# 15        DA JHS UPPER OBUASI (A)  149  251                415
# 16        DA JHS UPPER OBUASI (B)  154  244                413
# 17  COMMUNITY CENTRE UPPER OBUASI  104  168                279
# 18   DA PRIM SCH LOWER OBUASI (A)  171  213                394
# 19   DA PRIM SCH LOWER OBUASI (B)  139  236                392
# 20     MARKET SQUARE LOWER OBUASI  118  177                303
# 21          METH PRIM SCH GYAAMAN  165  299                486
# 23             DA JHS GYAAMAN (A)  106  170                281
# 24             DA JHS GYAAMAN (B)  142  163                313
# 25           METH. CHURCH GYAAMAN  140  169                311
# 26         METH. PRIM SCH ESIKUMA  176  242                451
# 27           METH. CHURCH ESIKUMA  128  145                282
# 36   COMMUNITY CENTRE ACHIASE (A)  158  161                333
#
#     Rejected votes  Total votes cast  Reg. votes  Percentage of votes
# 3               10               247         295            34.177215
# 4                2               222         273            31.363636
# 5                2               296         409            46.938776
# 6                6               319         407            40.255591
# 7                0               125         179            40.800000
# 13               3               254         296            48.207171
# 15              10               416         506            35.903614
# 16               5               418         505            37.288136
# 17              10               289         379            37.275986
# 18               2               396         536            43.401015
# 19               8               400         535            35.459184
# 20               5               308         457            38.943894
# 21               5               491         636            33.950617
# 23               3               284         511            37.722420
# 24               7               320         509            45.367412
# 25               2               313         441            45.016077
# 26               8               459         594            39.024390
# 27               6               288         364            45.390071
# 36               7               340         421            47.447447

# %%
# Percentage of losses among total poll 
percent_poll_loss = (npp_losses.shape[0]/df.shape[0])*100
percent_poll_loss
# Out:
# 22.61904761904762

# %%
# Percentage of Registered Voters who did not vote for winning polls
reg_vote_not = ((npp_losses['Reg. votes'] - npp_losses['Total votes cast']) / npp_losses['Reg. votes'])*100
npp_losses['Percentage of non-voters'] = reg_vote_not
npp_losses
# Out:
#              Polling station name  NPP  NDC  Total valid votes  \
# 3        DA PRIM SCH KWAME ADWER    81  153                237
# 4           DA PRIM SCH ABAMKWAIM   69  115                220
# 5         DA PRIM SCH AFRANSI (A)  138  144                294
# 6         DA PRIM SCH AFRANSI (B)  126  179                313
# 7                  DA JHS AFRANSI   51   64                125
# 13     ANGLICAN PRIM SCHOOL OFASO  121  126                251
# 15        DA JHS UPPER OBUASI (A)  149  251                415
# 16        DA JHS UPPER OBUASI (B)  154  244                413
# 17  COMMUNITY CENTRE UPPER OBUASI  104  168                279
# 18   DA PRIM SCH LOWER OBUASI (A)  171  213                394
# 19   DA PRIM SCH LOWER OBUASI (B)  139  236                392
# 20     MARKET SQUARE LOWER OBUASI  118  177                303
# 21          METH PRIM SCH GYAAMAN  165  299                486
# 23             DA JHS GYAAMAN (A)  106  170                281
# 24             DA JHS GYAAMAN (B)  142  163                313
# 25           METH. CHURCH GYAAMAN  140  169                311
# 26         METH. PRIM SCH ESIKUMA  176  242                451
# 27           METH. CHURCH ESIKUMA  128  145                282
# 36   COMMUNITY CENTRE ACHIASE (A)  158  161                333
#
#     Rejected votes  Total votes cast  Reg. votes  Percentage of votes  \
# 3               10               247         295            34.177215
# 4                2               222         273            31.363636
# 5                2               296         409            46.938776
# 6                6               319         407            40.255591
# 7                0               125         179            40.800000
# 13               3               254         296            48.207171
# 15              10               416         506            35.903614
# 16               5               418         505            37.288136
# 17              10               289         379            37.275986
# 18               2               396         536            43.401015
# 19               8               400         535            35.459184
# 20               5               308         457            38.943894
# 21               5               491         636            33.950617
# 23               3               284         511            37.722420
# 24               7               320         509            45.367412
# 25               2               313         441            45.016077
# 26               8               459         594            39.024390
# 27               6               288         364            45.390071
# 36               7               340         421            47.447447
#
#     Percentage of non-voters
# 3                  16.271186
# 4                  18.681319
# 5                  27.628362
# 6                  21.621622
# 7                  30.167598
# 13                 14.189189
# 15                 17.786561
# 16                 17.227723
# 17                 23.746702
# 18                 26.119403
# 19                 25.233645
# 20                 32.603939
# 21                 22.798742
# 23                 44.422701
# 24                 37.131631
# 25                 29.024943
# 26                 22.727273
# 27                 20.879121
# 36                 19.239905

# %%
# Percentage margin of loss over NDC
loss_margin_percent = ((npp_losses['NPP'] - npp_losses['NDC'])/ npp_losses['Total valid votes'])*100
npp_losses['Percentage of loss margin'] = loss_margin_percent
npp_losses
# Out:
#              Polling station name  NPP  NDC  Total valid votes  \
# 3        DA PRIM SCH KWAME ADWER    81  153                237
# 4           DA PRIM SCH ABAMKWAIM   69  115                220
# 5         DA PRIM SCH AFRANSI (A)  138  144                294
# 6         DA PRIM SCH AFRANSI (B)  126  179                313
# 7                  DA JHS AFRANSI   51   64                125
# 13     ANGLICAN PRIM SCHOOL OFASO  121  126                251
# 15        DA JHS UPPER OBUASI (A)  149  251                415
# 16        DA JHS UPPER OBUASI (B)  154  244                413
# 17  COMMUNITY CENTRE UPPER OBUASI  104  168                279
# 18   DA PRIM SCH LOWER OBUASI (A)  171  213                394
# 19   DA PRIM SCH LOWER OBUASI (B)  139  236                392
# 20     MARKET SQUARE LOWER OBUASI  118  177                303
# 21          METH PRIM SCH GYAAMAN  165  299                486
# 23             DA JHS GYAAMAN (A)  106  170                281
# 24             DA JHS GYAAMAN (B)  142  163                313
# 25           METH. CHURCH GYAAMAN  140  169                311
# 26         METH. PRIM SCH ESIKUMA  176  242                451
# 27           METH. CHURCH ESIKUMA  128  145                282
# 36   COMMUNITY CENTRE ACHIASE (A)  158  161                333
#
#     Rejected votes  Total votes cast  Reg. votes  Percentage of votes  \
# 3               10               247         295            34.177215
# 4                2               222         273            31.363636
# 5                2               296         409            46.938776
# 6                6               319         407            40.255591
# 7                0               125         179            40.800000
# 13               3               254         296            48.207171
# 15              10               416         506            35.903614
# 16               5               418         505            37.288136
# 17              10               289         379            37.275986
# 18               2               396         536            43.401015
# 19               8               400         535            35.459184
# 20               5               308         457            38.943894
# 21               5               491         636            33.950617
# 23               3               284         511            37.722420
# 24               7               320         509            45.367412
# 25               2               313         441            45.016077
# 26               8               459         594            39.024390
# 27               6               288         364            45.390071
# 36               7               340         421            47.447447
#
#     Percentage of non-voters  Percentage of loss margin
# 3                  16.271186                 -30.379747
# 4                  18.681319                 -20.909091
# 5                  27.628362                  -2.040816
# 6                  21.621622                 -16.932907
# 7                  30.167598                 -10.400000
# 13                 14.189189                  -1.992032
# 15                 17.786561                 -24.578313
# 16                 17.227723                 -21.791768
# 17                 23.746702                 -22.939068
# 18                 26.119403                 -10.659898
# 19                 25.233645                 -24.744898
# 20                 32.603939                 -19.471947
# 21                 22.798742                 -27.572016
# 23                 44.422701                 -22.775801
# 24                 37.131631                  -6.709265
# 25                 29.024943                  -9.324759
# 26                 22.727273                 -14.634146
# 27                 20.879121                  -6.028369
# 36                 19.239905                  -0.900901

# %%
# Saving cleaned to excel file
win_file_name = 'winselectionsdata.xlsx'
loss_file_name = 'losselectionsdata.xlsx'
npp_wins.to_excel(win_file_name)
npp_losses.to_excel(loss_file_name)
